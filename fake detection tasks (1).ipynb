# %%
import pandas as pd
df=pd.read_csv("fake_news.xls")

# %%
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
df.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
df.dropna()
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
df.isnull().sum()
# Out:
# id           0
# title      558
# author    1918
# text         0
# label        0
# dtype: int64

# %%
df=df.dropna(subset=["text"])

# %%
df.isnull().sum()
# Out:
# id           0
# title      558
# author    1918
# text         0
# label        0
# dtype: int64

# %%
x=df["text"]
y=df["label"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.25,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(stop_words="english")
x_train_tfidf=tfidf.fit_transform(x_train)
x_test_tfidf=tfidf.transform(x_test)

# %%
x_train_tfidf
# Out:
# <15570x154506 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4009467 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb_classifier=MultinomialNB()

# %%
nb_classifier.fit(x_train_tfidf,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=nb_classifier.predict(x_test_tfidf)

# %%
from sklearn.metrics import accuracy_score,classification_report

print("accuracy:", accuracy_score(y_test,y_pred))
print("classification report:", classification_report(y_test,y_pred))
# Out:
# accuracy: 0.8728568676555577
# classification report:               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89      2608
#            1       0.98      0.76      0.86      2583
#
#     accuracy                           0.87      5191
#    macro avg       0.89      0.87      0.87      5191
# weighted avg       0.89      0.87      0.87      5191

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
import pandas as pd

# %%
data=pd.read_csv("fake_or_real_news.xls")

# %%
data
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'title', 'text', 'label'], dtype='object')

# %%
data["label1"]=data["label"].apply(lambda x:1 if x=='REAL' else 0)

# %%
data
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label  label1
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE       0
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label  label1
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE       0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE       0
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL       1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE       0
# 4  It's primary day in New York and front-runners...  REAL       1

# %%
data.tail()
# Out:
#       Unnamed: 0                                              title  \
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label  label1
# 6330  The State Department told the Republican Natio...  REAL       1
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE       0
# 6332   Anti-Trump Protesters Are Tools of the Oligar...  FAKE       0
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL       1
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL       1

# %%
x=data["text"]
y=data["label1"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.25,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(stop_words="english")
x_train_tfidf=tfidf.fit_transform(x_train)
x_test_tfidf=tfidf.transform(x_test)

# %%
x_train_tfidf
# Out:
# <4751x59568 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1235785 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb_classifier=MultinomialNB()

# %%
nb_classifier.fit(x_train_tfidf,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=nb_classifier.predict(x_test_tfidf)

# %%
from sklearn.metrics import accuracy_score,classification_report
print("accuracy:", accuracy_score(y_test,y_pred))
print("classification report:"), classification_report(y_test,y_pred)
# Out:
# accuracy: 0.8320707070707071
# classification report:
# (None,
#  '              precision    recall  f1-score   support\n\n           0       0.97      0.68      0.80       794\n           1       0.76      0.98      0.85       790\n\n    accuracy                           0.83      1584\n   macro avg       0.86      0.83      0.83      1584\nweighted avg       0.86      0.83      0.83      1584\n')

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
new_data = [
    "The government is planning to launch a new healthcare scheme.",
    "Aliens have landed on Earth, scientists confirm!",
    "A man claims he found a dragon egg in his backyard!"
]

# %%
new_data_tfidf = tfidf.transform(new_data)

# %%
new_predictions = nb_classifier.predict(new_data_tfidf)

# %%
for i, text in enumerate(new_data):
    label = "Real" if new_predictions[i] == 1 else "Fake"
    print(f"Article: {text}\nPrediction: {label}\n")
# Out:
# Article: The government is planning to launch a new healthcare scheme.
# Prediction: Fake
#
# Article: Aliens have landed on Earth, scientists confirm!
# Prediction: Fake
#
# Article: A man claims he found a dragon egg in his backyard!
# Prediction: Fake
